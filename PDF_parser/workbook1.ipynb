# %% [markdown]
# # import

# %%
import layoutparser as lp

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
import torch

from PIL import Image
from IPython.display import display

# %% [markdown]
# # load data

# %%
file1 = "./AppleIncNasdaqGSAAPL_PublicCompany.pdf"

# %%
pdf_tokens, pdf_images = lp.load_pdf(file1, load_images=True)

# %%
for image in pdf_images:
    image.show()

# %% [markdown]
# # model

# %%
lp.draw_box(pdf_images[0], pdf_tokens[0])
# Out:
# <PIL.Image.Image image mode=RGB size=612x792>
